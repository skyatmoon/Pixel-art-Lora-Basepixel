# %%
! pip install clean-fid
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import cv2
from cleanfid import fid

# %%
score = fid.compute_fid("/content/drive/MyDrive/Lora/real", "/content/drive/MyDrive/Lora/generated", mode="clean", num_workers=0)
print(f"fid score is {score:.3f}")
# Out:
# compute FID between two folders
# Found 100 images in the folder /content/drive/MyDrive/Lora/real
# FID real : 100%|██████████| 4/4 [00:13<00:00,  3.26s/it]
# Found 100 images in the folder /content/drive/MyDrive/Lora/generated
# FID generated : 100%|██████████| 4/4 [00:07<00:00,  1.96s/it]
# clean-fid score is 210.992
